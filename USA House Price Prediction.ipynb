9925.650114  3.531176e+05
# min                        2.000000       172.610686  1.593866e+04
# 25%                        3.140000     29403.928700  9.975771e+05
# 50%                        4.050000     36199.406690  1.232669e+06
# 75%                        4.490000     42861.290770  1.471210e+06
# max                        6.500000     69621.713380  2.469066e+06

# %% [markdown]
# # Data Preprocessing
# Part-1: HANDLING MISSING DATA

# %%
# Finding the null value fron the dataset
housing.isnull().sum()
# Out:
# Avg. Area Income                10
# Avg. Area House Age              0
# Avg. Area Number of Rooms        5
# Avg. Area Number of Bedrooms     6
# Area Population                  0
# Price                            0
# Address                          0
# dtype: int64

# %%
housing.isnull().sum()/len(housing)*100
# Out:
# Avg. Area Income                0.20
# Avg. Area House Age             0.00
# Avg. Area Number of Rooms       0.10
# Avg. Area Number of Bedrooms    0.12
# Area Population                 0.00
# Price                           0.00
# Address                         0.00
# dtype: float64

# %%
# checking the distribution of missing data in column Avg. Area Income
sns.boxplot(y = 'Avg. Area Income', data= housing)
plt.show()

# %%
# filling the missing value in 'Avg. Area Income' column with median
housing['Avg. Area Income'] = housing['Avg. Area Income'].fillna(housing['Avg. Area Income'].median())

# %%
sns.boxplot(y = 'Avg. Area Number of Rooms', data = housing)
plt.show()

# %%
housing['Avg. Area Number of Rooms'] = housing['Avg. Area Number of Rooms'].fillna(housing['Avg. Area Number of Rooms'].median())

# %%
sns.boxplot(y = 'Avg. Area Number of Bedrooms', data=housing)
plt.show()

# %%
housing['Avg. Area Number of Bedrooms'] = housing['Avg. Area Number of Bedrooms'].fillna(housing['Avg. Area Number of Bedrooms'].mean())

# %%
# Again checking the null value
housing.isnull().sum()
# Out:
# Avg. Area Income                0
# Avg. Area House Age             0
# Avg. Area Number of Rooms       0
# Avg. Area Number of Bedrooms    0
# Area Population                 0
# Price                           0
# Address                         0
# dtype: int64

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Avg. Area Income              5000 non-null   float64
#  1   Avg. Area House Age           5000 non-null   float64
#  2   Avg. Area Number of Rooms     5000 non-null   float64
#  3   Avg. Area Number of Bedrooms  5000 non-null   float64
#  4   Area Population               5000 non-null   float64
#  5   Price                         5000 non-null   float64
#  6   Address                       5000 non-null   object
# dtypes: float64(6), object(1)
# memory usage: 273.6+ KB

# %%
# Missing value treatment is completed

# %% [markdown]
# Part 2- Encoding is not reuired for 'Address', as area information given

# %% [markdown]
# # Outlier Treatment

# %%
# let's drop the 'Address' column as area information is already given
housing = housing.iloc[:,0:-1]
housing.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0       79545.45857             5.682861                   7.009188
# 1       79248.64245             6.002900                   6.730821
# 2       61287.06718             5.865890                   8.512727
# 3       63345.24005             7.188236                   5.586729
# 4       59982.19723             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price
# 0                          4.09      23086.80050  1.059034e+06
# 1                          3.09      40173.07217  1.505891e+06
# 2                          5.13      36882.15940  1.058988e+06
# 3                          3.26      34310.24283  1.260617e+06
# 4                          4.23      26354.10947  6.309435e+05

# %%
def distplots(col):
    sns.distplot(housing[col])
    plt.show()
    
for i in list(housing.columns):
    distplots(i)
    plt.show()

# %%
def boxplots(col):
    sns.boxplot(housing[col])
    plt.xlabel(col)
    plt.show()
    
for i in list(housing.columns):
    boxplots(i)
    plt.show()

# %%
# Checking datatypes of features
housing.dtypes
# Out:
# Avg. Area Income                float64
# Avg. Area House Age             float64
# Avg. Area Number of Rooms       float64
# Avg. Area Number of Bedrooms    float64
# Area Population                 float64
# Price                           float64
# dtype: object

# %%
# we have to handle outlier for 'Avg. Area Income', 'Avg. Area House Age','Avg. Area number of Rooms' and 'Area Population'

# %%
income_q1 = housing['Avg. Area Income'].quantile(0.25)
income_q3 = housing['Avg. Area Income'].quantile(0.75)
income_iqr = income_q3 - income_q1
lower_limit = income_q1 - 1.5 * income_iqr
upper_limit = income_q3 + 1.5 * income_iqr

# %%
housing['Avg. Area Income'] = np.where(housing['Avg. Area Income'] > upper_limit, upper_limit,
                                      np.where(housing['Avg. Area Income'] < lower_limit,
                                              lower_limit, housing['Avg. Area Income']))

# %%
sns.boxplot(y= 'Avg. Area Income', data = housing)
plt.show()

# %%
income_q1 = housing['Avg. Area House Age'].quantile(0.25)
income_q3 = housing['Avg. Area House Age'].quantile(0.75)
income_iqr =income_q3 - income_q1
lower_limit = income_q1 - 1.5*income_iqr
upper_limit = income_q3  + 1.5 * income_iqr

# %%
housing['Avg. Area House Age'] = np.where(housing['Avg. Area House Age'] > upper_limit,upper_limit,
                                         np.where(housing['Avg. Area House Age']< lower_limit,lower_limit,
                                                 housing['Avg. Area House Age']))

# %%
sns.boxplot(y= 'Avg. Area House Age', data = housing)
plt.show()

# %%
income_q1 = housing['Avg. Area Number of Rooms'].quantile(0.25)
income_q3 = housing['Avg. Area Number of Rooms'].quantile(0.75)
income_iqr =income_q3 - income_q1
lower_limit = income_q1 - 1.5*income_iqr
upper_limit = income_q3  + 1.5 * income_iqr

# %%
housing['Avg. Area Number of Rooms'] = np.where(housing['Avg. Area Number of Rooms'] > upper_limit, upper_limit,
                                      np.where(housing['Avg. Area Number of Rooms'] < lower_limit,
                                              lower_limit, housing['Avg. Area Number of Rooms']))

# %%
sns.boxplot(y= 'Avg. Area Number of Rooms', data = housing)
plt.show()

# %%
income_q1 = housing['Area Population'].quantile(0.25)
income_q3 = housing['Area Population'].quantile(0.75)
income_iqr =income_q3 - income_q1
lower_limit = income_q1 - 1.5*income_iqr
upper_limit = income_q3  + 1.5 * income_iqr

# %%
housing['Area Population'] = np.where(housing['Area Population'] > upper_limit, upper_limit,
                                      np.where(housing['Area Population'] < lower_limit,
                                              lower_limit, housing['Area Population']))

# %%
sns.boxplot(y= 'Area Population', data = housing)
plt.show()

# %%
def boxplots(col):
    sns.boxplot(housing[col])
    plt.xlabel(col)
    plt.show()
    
for i in list(housing.select_dtypes(exclude=['object']).columns)[0:]:
    boxplots(i)

# %%
housing.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0       79545.45857             5.682861                   7.009188
# 1       79248.64245             6.002900                   6.730821
# 2       61287.06718             5.865890                   8.512727
# 3       63345.24005             7.188236                   5.586729
# 4       59982.19723             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price
# 0                          4.09      23086.80050  1.059034e+06
# 1                          3.09      40173.07217  1.505891e+06
# 2                          5.13      36882.15940  1.058988e+06
# 3                          3.26      34310.24283  1.260617e+06
# 4                          4.23      26354.10947  6.309435e+05

# %%
# Part 1 : Missing value treatement - done 
# Part 2 - Encoding Treatement - not required, as all the features have numeric data type.
# Part 3 - Outlier Treatment - done
# Part 4 - Feature Scaling - first we have to split the data into indepednet and dependent varialbe
x = housing.iloc[:,0:-1] # Independent variable
y = housing.iloc[:,-1] # Dependent variable (Price)

# %%
x.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0       79545.45857             5.682861                   7.009188
# 1       79248.64245             6.002900                   6.730821
# 2       61287.06718             5.865890                   8.512727
# 3       63345.24005             7.188236                   5.586729
# 4       59982.19723             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population
# 0                          4.09      23086.80050
# 1                          3.09      40173.07217
# 2                          5.13      36882.15940
# 3                          3.26      34310.24283
# 4                          4.23      26354.10947

# %%
y.head()
# Out:
# 0    1.059034e+06
# 1    1.505891e+06
# 2    1.058988e+06
# 3    1.260617e+06
# 4    6.309435e+05
# Name: Price, dtype: float64

# %% [markdown]
# Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
sc_x = scaler.fit_transform(x)
pd.DataFrame(sc_x)
# Out:
#              0         1         2         3         4
# 0     1.036382 -0.298541  0.021620  0.087648 -1.325622
# 1     1.008309  0.025747 -0.256381 -0.722966  0.407049
# 2    -0.690457 -0.113082  1.523179  0.930687  0.073326
# 3    -0.495800  1.226822 -1.398967 -0.585161 -0.187484
# 4    -0.813869 -0.949376  0.850726  0.201134 -0.994293
# ...        ...       ...       ...       ...       ...
# 4995 -0.758470  1.877474 -0.849064 -0.423039 -1.350917
# 4996  0.936679  1.035210 -0.410236  0.030905 -1.069131
# 4997 -0.491501  1.290004 -2.179585 -1.501155 -0.293363
# 4998 -0.055437 -0.448985  0.142416  1.181977  0.655755
# 4999 -0.291006  0.015012 -0.194947  0.071436  1.048775
#
# [5000 rows x 5 columns]

# %%
pd.DataFrame(sc_x).describe()
# Out:
#                   0             1             2             3             4
# count  5.000000e+03  5.000000e+03  5.000000e+03  5.000000e+03  5.000000e+03
# mean  -4.160228e-16 -1.573852e-16 -2.913225e-16 -3.836931e-17  3.439027e-16
# std    1.000100e+00  1.000100e+00  1.000100e+00  1.000100e+00  1.000100e+00
# min   -2.697774e+00 -2.683155e+00 -2.732629e+00 -1.606535e+00 -2.732030e+00
# 25%   -6.717228e-01 -6.639070e-01 -6.869427e-01 -6.824351e-01 -6.850199e-01
# 50%    1.987953e-02 -7.155075e-03  1.537949e-02  5.522369e-02  4.090352e-03
# 75%    6.789778e-01  6.822584e-01  6.768483e-01  4.118939e-01  6.796532e-01
# max    2.705029e+00  2.701506e+00  2.722535e+00  2.041228e+00  2.726663e+00

# %%
# It's multiple linear regression, hence we have to check "Multicollinearity"
var = sc_x
var.shape
# Out:
# (5000, 5)

# %% [markdown]
# # Check Multicollinearity - VIF (Variance Inflation Factor)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
var = sc_x
vif = pd.DataFrame()
vif['variance_inflation_factor'] = [variance_inflation_factor(var,i) for i in range(var.shape[1])]

# %%
vif['features'] = x.columns

# %%
vif
# Out:
#    variance_inflation_factor                      features
# 0                   1.001066              Avg. Area Income
# 1                   1.000593           Avg. Area House Age
# 2                   1.274838     Avg. Area Number of Rooms
# 3                   1.275700  Avg. Area Number of Bedrooms
# 4                   1.001142               Area Population

# %% [markdown]
# # Finding Correlation

# %%
plt.figure(figsize=(20,16))
sns.heatmap(housing.corr(), annot=True, cmap ='rainbow')
plt.show()

# %%
# split the data into training and testing whereas training is for building a model and testing is for predicting and evaluation
from sklearn.model_selection import train_test_split
x_train1, x_test1, y_train1, y_test1 = train_test_split(sc_x,y,test_size = 0.2, random_state=19)

# %%
print(x_train1.shape)
print(x_test1.shape)
# Out:
# (4000, 5)
# (1000, 5)

# %%
print(y_train1.shape)
print(y_test1.shape)
# Out:
# (4000,)
# (1000,)

# %%
x_test1
# Out:
# array([[-2.13720844,  0.82227144,  0.21932176, -0.50409999,  0.54706828],
#        [ 0.01987953,  2.14411853, -1.94223256,  0.09575439,  1.12209974],
#        [-2.17870169,  0.95201372, -0.54580539, -1.21744033,  1.38727565],
#        ...,
#        [ 1.07333954,  0.57629691,  1.6582648 ,  0.84151929, -1.26795398],
#        [ 0.18677973,  1.07383265, -1.97214704, -0.40682631, -1.02277743],
#        [ 0.53900866,  1.13870107, -0.65019742, -1.24986489, -0.27578966]])

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2, random_state=1)

# %%
print(x_train.shape)
print(x_test.shape)
# Out:
# (4000, 5)
# (1000, 5)

# %%
x_test
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 2764      75012.341660             6.742828                   6.604335
# 4767      76187.273310             6.156222                   7.166149
# 3814      67622.219610             5.813928                   5.071112
# 3499      66933.165270             4.748787                   5.879803
# 2735      65192.105630             6.275509                   8.017889
# ...                ...                  ...                        ...
# 448       66356.059960             7.480941                   6.725864
# 921       68008.615430             4.357088                   7.879545
# 4087      97188.572468             5.870726                   6.644853
# 1242      62798.232980             5.890872                   6.481651
# 2242      40063.096827             6.965104                   8.966906
#
#       Avg. Area Number of Bedrooms  Area Population
# 2764                          4.10      42877.42415
# 4767                          3.32      45084.39424
# 3814                          4.16      35359.84847
# 3499                          2.09      41834.04294
# 2735                          4.47      26228.39458
# ...                            ...              ...
# 448                           3.19      38022.83820
# 921                           5.41      28908.08678
# 4087                          4.33      26041.48762
# 1242                          3.05      34652.25789
# 2242                          4.22      25432.07677
#
# [1000 rows x 5 columns]

# %% [markdown]
# # Building Model - Linear Regression
# 1. Basic Method

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
print(lm.coef_)
# Out:
# [2.17935499e+01 1.66081530e+05 1.21361281e+05 1.55748744e+03
#  1.52299584e+01]

# %%
print(lm.intercept_)
# Out:
# -2659096.292237672

# %%
x.columns
# Out:
# Index(['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
#        'Avg. Area Number of Bedrooms', 'Area Population'],
#       dtype='object')

# %%
# price = 'Avg. Area Income' * 2.17935499e+01 + 'Avg. Area House Age'*1.66081530e+05 + 'Avg. Area Number of Rooms' * 1.21361281e+05 + 'Avg. Area Number of Bedrooms' * 1.55748744e+03 + 'Area Population'* 1.52299584e+01 + lm.intercept_

# %%
# Predicting  test dataset with linear model
y_pred = lm.predict(x_test)
y_pred
# Out:
# array([1556465.75926579, 1585226.89003298,  940662.73808574,
#         942267.08267994, 1183397.82758251,  352823.84635161,
#        1932168.26763532, 1069159.90008016, 1651895.56262053,
#        1072341.45812552,  623454.40631307, 1541176.46360573,
#        1633803.09679068, 1053638.24469208,  959794.3876728 ,
#        1234850.93374237, 1430229.65767012,  924373.47470039,
#        1127662.21794384, 1159199.12739994, 1297090.80061078,
#        1869228.52698161, 1183194.63467132, 1191357.56435619,
#        1559609.1321101 , 1866172.97150424,  812506.06173236,
#        1062654.01455249, 1226189.15910378,  658226.42397833,
#         840997.6376942 , 1639226.6671293 ,  663042.91343843,
#        1116529.14900466,  798271.14857516, 1304758.90145386,
#        1147381.22377372, 1350979.52554209, 1033743.2575199 ,
#        1162614.34647005, 1414130.23000875, 1310297.72104033,
#        1579262.60017852, 1301102.46703985,  846865.97358646,
#         922617.25833651, 1229516.11291232, 1161619.43868295,
#        1423220.00381719, 1335072.41089391, 1573480.63031525,
#         745004.01455223,  754592.66816224, 1036533.30819081,
#        1232927.18767062, 1310878.87585731, 1544692.53265618,
#        1074145.05155392, 1048825.42299655, 1587860.25835181,
#        1438693.62879115, 1035031.98089871, 1722251.46806683,
#        1583023.37454554, 1600172.070991  , 1883535.95430153,
#        1767753.97523498, 1063484.54485993,  633209.37729003,
#        1012588.84416016, 1336616.04815807, 1117285.63020767,
#        1279788.62789804,  716638.24170663, 1730582.73567283,
#        1900469.81827987, 1208925.64653082,  866666.30392569,
#        1088958.37362884,  594556.02299558, 1272536.082332  ,
#         638126.57261527,  868879.65948012,  773589.22050766,
#        1038187.41701259,  974552.40744341,  774374.41438096,
#        1196369.62242006, 1113815.39819372,  607182.23133959,
#        1097243.79222482, 1653686.63187076, 1541769.28890113,
#        1216847.74479275,  833280.47463994, 1208719.84882116,
#        1428273.01772647, 1395932.35009844, 1025121.70739566,
#        1755343.88095212,  654388.62933001, 1060747.37140647,
#        1503111.01423918, 1386044.99600338, 1596858.85885533,
#        1154996.68464249, 1077211.18718823, 1612501.88340324,
#        1443969.1720362 , 1066778.26833941, 1171788.07090001,
#         731786.28440892, 1555037.09601842, 1050365.74536078,
#        1187483.71548664, 1832546.74299818, 1278807.23470245,
#         787248.53259189, 1418662.70821229, 1161746.22445646,
#        1754896.02623567, 1512107.38110933,  799142.58999879,
#        1644963.1292783 , 1377833.00496098, 1831319.46813539,
#        1145635.70741584, 1192055.29698346,  915260.69428292,
#        1889895.16143855, 1612279.30408715,  927754.04714502,
#        1757206.51634653,  878977.03950398, 1004242.23183366,
#         544291.02333032, 1021491.94698983, 1588010.37244444,
#        1573659.81629514, 1127499.11378917, 1178923.05660541,
#        1118268.03161027, 1426021.05536363, 1780484.61077536,
#         998601.97507952,  972767.84747636, 1739341.99873943,
#        1413138.98871474,  908808.64407189, 1829067.98699186,
#        1552806.8906793 , 1104116.36178784, 1391791.44918196,
#        1712989.34200981, 1245817.28674925,  840134.09120887,
#         630931.54051115, 1244938.65233288,  888711.72830034,
#        1340787.30378821,  883794.08653229, 1588432.89797075,
#        1792033.84492769, 1238641.99521939, 1284567.79869938,
#         983938.55228753,  889100.15334843, 1002811.07710776,
#        1119049.54720389,  834854.0105182 , 1512544.31881067,
#        1300177.75799952, 1231951.31973641,  688827.43119286,
#        1197591.07400219,  652946.39959864, 1537231.38612496,
#        2153324.53140904, 1215280.56045689, 1700572.55213444,
#        1115629.16902095, 1123687.85451304,  750027.61743285,
#        1353855.65663543, 1197749.24125357, 1188971.34267764,
#        1651970.61138236, 1251718.84023441,  835865.75567404,
#        1119234.02250879, 1364100.21798548, 1634237.95608609,
#        1331899.68118126, 1584987.69300699,  979694.33854544,
#        1669467.44652605,  992277.92649156, 1429390.85592161,
#        1195915.34125974, 1347280.93915696,  786875.80092466,
#         996483.48728023, 1236459.59816507, 1148553.69316541,
#        1212838.86741383, 1111257.90382731, 1429798.11313784,
#         951651.35315167, 1643789.48423174, 1006989.52434354,
#         852933.11682138])

# %%
y_test
# Out:
# 2764    1.413580e+06
# 4767    1.618721e+06
# 3814    8.413925e+05
# 3499    8.814439e+05
# 2735    1.174748e+06
#             ...
# 448     1.309986e+06
# 921     1.059871e+06
# 4087    1.644923e+06
# 1242    1.106337e+06
# 2242    7.590447e+05
# Name: Price, Length: 1000, dtype: float64

# %% [markdown]
# # Evaluation of Linear Model

# %%
# Approch no- 1
from sklearn.metrics import r2_score
print("Accuracy:", r2_score(y_test,y_pred))
# Out:
# Accuracy: 0.9170513818868028

# %%
# Approch no-2: OLS Method
from statsmodels.regression.linear_model import OLS
import statsmodels.regression.linear_model as smf

# %%
reg_model = smf.OLS(endog = y_train, exog = x_train).fit()

# %%
reg_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                  Price   R-squared (uncentered):                   0.965
# Model:                            OLS   Adj. R-squared (uncentered):              0.965
# Method:                 Least Squares   F-statistic:                          2.185e+04
# Date:                Thu, 06 Jun 2024   Prob (F-statistic):                        0.00
# Time:                        14:47:10   Log-Likelihood:                         -55243.
# No. Observations:                4000   AIC:                                  1.105e+05
# Df Residuals:                    3995   BIC:                                  1.105e+05
# Df Model:                           5
# Covariance Type:            nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Avg. Area Income                10.1935      0.300     33.942      0.000       9.605      10.782
# Avg. Area House Age           5.178e+04   3290.382     15.737      0.000    4.53e+04    5.82e+04
# Avg. Area Number of Rooms    -9178.9208   3678.433     -2.495      0.013   -1.64e+04   -1967.140
# Avg. Area Number of Bedrooms  4276.6383   3484.677      1.227      0.220   -2555.272    1.11e+04
# Area Population                  8.0204      0.366     21.924      0.000       7.303       8.738
# ==============================================================================
# Omnibus:                        0.592   Durbin-Watson:                   1.944
# Prob(Omnibus):                  0.744   Jarque-Bera (JB):                0.635
# Skew:                           0.024   Prob(JB):                        0.728
# Kurtosis:                       2.962   Cond. No.                     9.37e+04
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The condition number is large, 9.37e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
# Using backward elimination 
# here Avg. Area Number of Bedrooms variable is non-significant basis p-value
x = x.drop(['Avg. Area Number of Bedrooms'], axis=1)

# %%
x.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0       79545.45857             5.682861                   7.009188
# 1       79248.64245             6.002900                   6.730821
# 2       61287.06718             5.865890                   8.512727
# 3       63345.24005             7.188236                   5.586729
# 4       59982.19723             5.040555                   7.839388
#
#    Area Population
# 0      23086.80050
# 1      40173.07217
# 2      36882.15940
# 3      34310.24283
# 4      26354.10947

# %%
# There is no fixed threshold value. basis experience, we use 70-30,75-25,80-20. by default system consider 75-25 
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2, random_state=0)

# %%
reg_model = smf.OLS(endog = y_train, exog=x_train).fit()
reg_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                  Price   R-squared (uncentered):                   0.964
# Model:                            OLS   Adj. R-squared (uncentered):              0.964
# Method:                 Least Squares   F-statistic:                          2.680e+04
# Date:                Thu, 06 Jun 2024   Prob (F-statistic):                        0.00
# Time:                        14:47:10   Log-Likelihood:                         -55278.
# No. Observations:                4000   AIC:                                  1.106e+05
# Df Residuals:                    3996   BIC:                                  1.106e+05
# Df Model:                           4
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Avg. Area Income             10.3008      0.303     34.052      0.000       9.708      10.894
# Avg. Area House Age        5.246e+04   3320.148     15.800      0.000     4.6e+04     5.9e+04
# Avg. Area Number of Rooms -8666.5831   3071.658     -2.821      0.005   -1.47e+04   -2644.419
# Area Population               8.0411      0.370     21.756      0.000       7.316       8.766
# ==============================================================================
# Omnibus:                        0.177   Durbin-Watson:                   1.979
# Prob(Omnibus):                  0.915   Jarque-Bera (JB):                0.161
# Skew:                          -0.015   Prob(JB):                        0.922
# Kurtosis:                       3.008   Cond. No.                     7.78e+04
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The condition number is large, 7.78e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
# Accuracy : Adj. R-squared (uncentered):   0.964
# p-value - all variable are statically significant (p<=0.05)
# All the Assumption are satisfied
# 1) Multicollinearity Not found  (vif is less than 5)
# 2) Endogenity - selected right dependent variable
# 3) Hetroscedasticity - handled outlier
# 4) Autocorrelation - Durbin-Watson:   1.979 (p-value <=0.05) - satisfied (no autocorrelation found)
# 5) Check Linearity - satisfied
# 6) Normality of Residual

# %%
sns.distplot((y_test - y_pred), bins=50)
plt.show()

# %% [markdown]
# # Regularisation Method
#     1.Lasso - L1 regularization
#     2.Ridge - L2 regularization *************************** very significant
#     3.ElasticNet : (L1 + L2) regularization - combination of lasso and ridge

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(x_train, y_train)
print("lm model", lm.coef_)
# Out:
# lm model [2.17682214e+01 1.67119475e+05 1.21923880e+05 1.53728286e+01]

# %%
y_pred_lm_train = lm.predict(x_train)
y_pred_lm_test = lm.predict(x_test)

# %%
print("LM_Train_ACC :", r2_score(y_train, y_pred_lm_train))
print("LM_Test_ACC :", r2_score(y_test, y_pred_lm_test))
# Out:
# LM_Train_ACC : 0.9174417841490737
# LM_Test_ACC : 0.9090675761687936

# %% [markdown]
# # Lasso method

# %%
# exact zero or closure to zero (slope/coefficient)
from sklearn.linear_model import Lasso
lasso = Lasso(alpha = 0.3)
lasso.fit(x_train, y_train)
print("Lasso Regularisation" , lasso.coef_)
# Out:
# Lasso Regularisation [2.17682209e+01 1.67119165e+05 1.21923578e+05 1.53728278e+01]

# %%
y_pred_lasso_train = lasso.predict(x_train)
y_pred_lasso_test = lasso.predict(x_test)

# %%
print("Lasso_Train_ACC :", r2_score(y_train, y_pred_lasso_train)) 
print("Lasso_Test_ACC :", r2_score(y_test, y_pred_lasso_test))
# Out:
# Lasso_Train_ACC : 0.9174417841476048
# Lasso_Test_ACC : 0.9090675904329609

# %% [markdown]
# # Ridge Regularization (L2)

# %%
from sklearn.linear_model import Ridge
ridge = Ridge(alpha=0.3)
ridge.fit(x_train, y_train)
print("Ridge Model :", ridge.coef_)
# Out:
# Ridge Model : [2.17682038e+01 1.67106582e+05 1.21914624e+05 1.53727952e+01]

# %%
y_pred_ridge_train = ridge.predict(x_train)
y_pred_ridge_test = ridge.predict(x_test)

# %%
print("Ridge_Train_ACC :", r2_score(y_train, y_pred_ridge_train))
print()
print("Ridge_Test_ACC :", r2_score(y_test, y_pred_ridge_test))
# Out:
# Ridge_Train_ACC : 0.9174417821784161
#
# Ridge_Test_ACC : 0.9090681939666867

# %% [markdown]
# # ElasticNet Regularization (L1 + L2)

# %%
from sklearn.linear_model import ElasticNet
elasticnet = ElasticNet(alpha=0.3, l1_ratio=0.1)
elasticnet.fit(x_train, y_train)
# Out:
# ElasticNet(alpha=0.3, l1_ratio=0.1)

# %%
y_pred_elastic_train = elasticnet.predict(x_train)
y_pred_elastic_test = elasticnet.predict(x_test)

# %%
print("ElasticNet_Train_ACC :", r2_score(y_train, y_pred_elastic_train))
print()
print("ElasticNet_Test_ACC :", r2_score(y_test, y_pred_elastic_test))
# Out:
# ElasticNet_Train_ACC : 0.901758288938795
#
# ElasticNet_Test_ACC : 0.8952016550808377

# %% [markdown]
# # Cross Validation Score - K-Fold method

# %%
from sklearn.model_selection import cross_val_score
training_accuracy = cross_val_score(lm, x_train, y_train, cv=10)

# %%
print('training_accuracy for all 10 indivisual :', training_accuracy)
print()
print("training_accuracy with mean value :", training_accuracy.mean())
print()
print("training_accuracy max value :", training_accuracy.max())
# Out:
# training_accuracy for all 10 indivisual : [0.92583402 0.92298199 0.92757644 0.9173837  0.91122926 0.90376145
#  0.90787634 0.91962723 0.92081829 0.90862776]
#
# training_accuracy with mean value : 0.9165716482072753
#
# training_accuracy max value : 0.9275764395226995

# %% [markdown]
# # Performance matrix

# %%
## Mean Absolute Error - MAE
from sklearn import metrics
print("MAE :", metrics.mean_absolute_error(y_test, y_pred_lm_test))
# Out:
# MAE : 83790.55810773488

# %%
# Mean Absolute Percent Error
print("MAPE :", metrics.mean_absolute_error(y_test, y_pred_lm_test)/y_test*100)
# Out:
# MAPE : 398      9.369914
# 3833     8.980966
# 4836     9.100271
# 4572    12.111001
# 636     11.435343
#           ...
# 4228    11.098667
# 2367     6.950295
# 788     12.538701
# 1452     5.990345
# 3265     6.559561
# Name: Price, Length: 1000, dtype: float64

# %%
# Mean Squared Error 
print("MSE :", metrics.mean_squared_error(y_test, y_pred_lm_test))
# Out:
# MSE : 11239140378.969656

# %%
# Root Mean Squared Error
print("MSE :", np.sqrt(metrics.mean_squared_error(y_test, y_pred_lm_test)))
# Out:
# MSE : 106014.81207345348
